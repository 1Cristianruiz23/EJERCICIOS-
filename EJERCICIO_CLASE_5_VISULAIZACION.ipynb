# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.5 MB 8.6 MB/s eta 0:00:02
#    ------------- -------------------------- 3.9/11.5 MB 10.0 MB/s eta 0:00:01
#    --------------------- ------------------ 6.0/11.5 MB 10.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.5 MB 10.4 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 10.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ------ --------------------------------- 2.1/12.6 MB 11.1 MB/s eta 0:00:01
#    -------------- ------------------------- 4.5/12.6 MB 11.2 MB/s eta 0:00:01
#    --------------------- ------------------ 6.8/12.6 MB 11.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.2/12.6 MB 11.1 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
# Cargar el archivo
df = pd.read_csv("C:\\Users\\Usuario\\Documents\\datos imb\\title.basics.tsv", sep="\t", low_memory=False)
df.head
# Out:
# <bound method NDFrame.head of              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short               Poor Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 11681112  tt9916848  tvEpisode              Episode #3.17
# 11681113  tt9916850  tvEpisode              Episode #3.19
# 11681114  tt9916852  tvEpisode              Episode #3.20
# 11681115  tt9916856      short                   The Wind
# 11681116  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short               Poor Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 11681112  tt9916848  tvEpisode              Episode #3.17
# 11681113  tt9916850  tvEpisode              Episode #3.19
# 11681114  tt9916852  tvEpisode              Episode #3.20
# 11681115  tt9916856      short                   The Wind
# 11681116  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# ...

# %%
df.columns
# Out:
# Index(['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult',
#        'startYear', 'endYear', 'runtimeMinutes', 'genres'],
#       dtype='object')

# %%
print("Tipos de datos:\n", df.dtypes) #data types - tipos de datos
# Out:
# Tipos de datos:
#  tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           object
# startYear         object
# endYear           object
# runtimeMinutes    object
# genres            object
# dtype: object

# %%
df[df['titleType'] == 'movie'].shape[0]
# Out:
# 715824

# %%
df['genres'].value_counts()
# Out:
# genres
# Drama                          1314605
# Comedy                          759710
# Talk-Show                       738664
# News                            608837
# Documentary                     563031
#                                 ...
# Animation,Horror,Talk-Show           1
# Animation,Biography,Western          1
# Talk-Show,Thriller                   1
# Biography,Crime,Fantasy              1
# Action,Biography,News                1
# Name: count, Length: 2388, dtype: int64

# %%
print("Ver Tipo , Titulo principal , duracion:")
df[['titleType', 'primaryTitle', 'runtimeMinutes']]
# Out:
# Ver Tipo , Titulo principal , duracion:
#           titleType               primaryTitle runtimeMinutes
# 0             short                 Carmencita              1
# 1             short     Le clown et ses chiens              5
# 2             short               Poor Pierrot              5
# 3             short                Un bon bock             12
# 4             short           Blacksmith Scene              1
# ...             ...                        ...            ...
# 11681112  tvEpisode              Episode #3.17             \N
# 11681113  tvEpisode              Episode #3.19             \N
# 11681114  tvEpisode              Episode #3.20             \N
# 11681115      short                   The Wind             27
# 11681116  tvEpisode  Horrid Henry Knows It All             10
#
# [11681117 rows x 3 columns]

# %%
print("Ordenado por cantidad de minutos")
df.sort_values(by= "runtimeMinutes", ascending=False)
# Out:
# Ordenado por cantidad de minutos
#              tconst  titleType                      primaryTitle  \
# 5840558  tt22984284      short                    Game of Clones
# 6924950  tt28752086  tvEpisode                     Episode #1.38
# 6924897  tt28752005  tvEpisode                    Episode #1.484
# 6924898  tt28752006  tvEpisode       Episode dated 3 August 2010
# 6924899  tt28752008  tvEpisode                    Episode #1.486
# ...             ...        ...                               ...
# 0         tt0000001      short                        Carmencita
# 436283    tt0454640      short                          The Talk
# 333156    tt0348126      short  Storm P. tegner de Tree Små Mænd
# 896384    tt0926344      short                               V-r
# 803662    tt0830188      short                   The Last Flight
#
#                             originalTitle isAdult startYear endYear  \
# 5840558                    Game of Clones       0      2021      \N
# ...
